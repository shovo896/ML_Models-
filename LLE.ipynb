# %%
import numpy as np 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import make_swiss_roll
from sklearn.manifold import LocallyLinearEmbedding
from sklearn.decomposition import PCA

# %% [markdown]
# Generating datasets

# %%
X,swiss_roll=make_swiss_roll(n_samples=1500,noise=0.05)

# %% [markdown]
# Applying Locally Linear Embedding

# %%
lle=LocallyLinearEmbedding(n_neighbors=12,n_components=2)
X_lle=lle.fit_transform(X)
lle_error=lle.reconstruction_error_

# %% [markdown]
# ploting orginal swiss roll in 3d

# %%
fig=plt.figure(figsize=(12,6))
ax=fig.add_subplot(121,projection='3d')
ax.scatter(X[:,0],X[:,1],X[:,2],cmap=plt.cm.Spectral,c=swiss_roll)
ax.set_title("Original swiss roll",fontsize=15)
# Out:
# Text(0.5, 0.92, 'Original swiss roll')

# %% [markdown]
# plotting 2d form

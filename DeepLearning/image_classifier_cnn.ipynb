# %%
import torch 
import torchvision 
import matplotlib.pyplot as plt 
import numpy as np 
import ssl 
ssl._create_default_https_context=ssl._create_unverified_context
plt.rcParams['figure.figsize']=14,6

# %% [markdown]
# cifar-10 dataset laod korbo

# %%
normalize_dataset=torchvision.transforms.compose([torchvision.transforms.ToTensor(),torchvision.transforms.Normalize(mean=(0.5,0.5,0.5),std=(0.5,0.5,0.5))])

# %%
train_dataset = torchvision.datasets.CIFAR10(
    root="./CIFAR10/train", train=True, transform=normalize_transform, download=True)
test_dataset = torchvision.datasets.CIFAR10(
    root="./CIFAR10/test", train=False, transform=normalize_transform, download=True)

# %%
import tensorflow as tf 
from tensorflow.keras.datasets import mnist 
from tensorflow.keras.utils import to_categorical

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train=x_train.reshape(-1,784).astype('float32')/255.0
x_test=x_test.reshape(-1,784).astype('float32')/255.0
model=tf.keras.Sequential([tf.keras.layers.Dense(64,activation='relu',input_shape=(784,)),tf.keras.layers.Dense(10,activation='softmax)])')])

model.compile(tf.keras.optimizers.Adagrad(learning_rate=0.01),loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=5)
# Out:
# C:\Users\Shuvo\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       2 x_train=x_train.reshape(-1,784).astype('float32')/255.0
#       3 x_test=x_test.reshape(-1,784).astype('float32')/255.0
# ----> 4 model=tf.keras.Sequential([tf.keras.layers.Dense(64,activation='relu',input_shape=(784,)),tf.keras.layers.Dense(10,activation='softmax)])')])
#       6 model.compile(tf.keras.optimizers.Adagrad(learning_rate=0.01),loss='sparse_categorical_crossentropy',metrics=['accuracy'])
#       7 model.fit(x_train,y_train,epochs=5)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\core\dense.py:94, in Dense.__init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, lora_rank, lora_alpha, **kwargs)
#      92 super().__init__(activity_regularizer=activity_regularizer, **kwargs)
#      93 self.units = units
# ---> 94 self.activation = activations.get(activation)
#      95 self.use_bias = use_bias
#      96 self.kernel_initializer = initializers.get(kernel_initializer)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\keras\src\activations\__init__.py:128, in get(identifier)
#     126 if callable(obj):
#     127     return obj
# --> 128 raise ValueError(
#     129     f"Could not interpret activation function identifier: {identifier}"
#     130 )
#
# ValueError: Could not interpret activation function identifier: softmax)])
